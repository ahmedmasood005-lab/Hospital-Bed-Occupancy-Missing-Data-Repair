# %% [markdown]
# # 06 Evaluation and Explainability
#
# This executable notebook is part of the Hospital Bed Occupancy Missing-Data Repair capstone.

# %%
from pathlib import Path
import pandas as pd
ROOT = Path.cwd().parents[0] if Path.cwd().name == 'notebooks' else Path.cwd()
comparison = pd.read_csv(ROOT / 'reports/model_comparison.csv')
report = pd.read_csv(ROOT / 'reports/classification_report.csv')
importance = pd.read_csv(ROOT / 'reports/permutation_importance.csv')
comparison

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.barplot(data=importance, x='importance_mean', y='feature'); plt.show()
