# %% [markdown]
# # 01 Data Loading
#
# This executable notebook is part of the Hospital Bed Occupancy Missing-Data Repair capstone.

# %%
from pathlib import Path
import pandas as pd
ROOT = Path.cwd().parents[0] if Path.cwd().name == 'notebooks' else Path.cwd()
raw = pd.read_csv(ROOT / 'data/raw/hospital_census_missing.csv', parse_dates=['Date'])
raw.head()

# %%
raw.info(); raw.isna().mean().sort_values(ascending=False)
