# %% [markdown]
# # 04 Feature Engineering
#
# This executable notebook is part of the Hospital Bed Occupancy Missing-Data Repair capstone.

# %%
from pathlib import Path
import pandas as pd
from src.feature_engineering import HospitalFeatureEngineer
ROOT = Path.cwd().parents[0] if Path.cwd().name == 'notebooks' else Path.cwd()
clean = pd.read_csv(ROOT / 'data/processed/hospital_census_clean.csv', parse_dates=['Date'])
engineered = HospitalFeatureEngineer().transform(clean)
engineered.head()

# %%
engineered.filter(regex='Lag|Rolling|Moving|Ratio|Interaction').head()
