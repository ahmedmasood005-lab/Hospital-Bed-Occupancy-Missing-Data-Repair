# %% [markdown]
# # 03 Preprocessing and Imputation
#
# This executable notebook is part of the Hospital Bed Occupancy Missing-Data Repair capstone.

# %%
from pathlib import Path
from src.data_loader import load_hospital_data
from src.preprocessing import DataPreprocessor
ROOT = Path.cwd().parents[0] if Path.cwd().name == 'notebooks' else Path.cwd()
raw = load_hospital_data(ROOT / 'data/raw/hospital_census_missing.csv')
preprocessor = DataPreprocessor()
cleaned = preprocessor.clean_types_and_duplicates(raw)
preprocessor.duplicate_count_

# %%
from src.imputation import ImputationComparator
reference = load_hospital_data(ROOT / 'data/raw/hospital_census_complete.csv')
metrics, recommendations, method_summary = ImputationComparator().benchmark(reference, benchmark_rows=800)
recommendations
