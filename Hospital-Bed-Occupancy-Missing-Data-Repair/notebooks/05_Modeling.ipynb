# %% [markdown]
# # 05 Modeling
#
# This executable notebook is part of the Hospital Bed Occupancy Missing-Data Repair capstone.

# %%
from pathlib import Path
import pandas as pd
from src.config import ProjectConfig
from src.modeling import OccupancyModelTrainer
ROOT = Path.cwd().parents[0] if Path.cwd().name == 'notebooks' else Path.cwd()
engineered = pd.read_csv(ROOT / 'data/engineered/hospital_census_engineered.csv', parse_dates=['Date'])
result = OccupancyModelTrainer(ProjectConfig(root_dir=ROOT)).train(engineered)
result.comparison

# %%
result.test_metrics
